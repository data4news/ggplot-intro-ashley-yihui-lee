# %% [markdown]
# # Python and R
#
# This setup allows you to use *Python* and *R* in the same notebook.
#
# To set up a similar notebook, see quickstart instructions here:
#
# https://github.com/dmil/jupyter-quickstart

# %%
# !pip install rpy2
# Out:
# Requirement already satisfied: rpy2 in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (3.5.17)
# Requirement already satisfied: cffi>=1.15.1 in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from rpy2) (1.17.1)
# Requirement already satisfied: jinja2 in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from rpy2) (3.1.4)
# Requirement already satisfied: tzlocal in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from rpy2) (5.2)
# Requirement already satisfied: pycparser in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from cffi>=1.15.1->rpy2) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ashleylee/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from jinja2->rpy2) (3.0.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# EXAMPLE PYTHON CELL

df = pd.read_csv('housing_data.csv')
df
# Out:
#        zip  population    borough  pct_hispanic_or_latino  pct_asian  \
# 0    11368      112088     QUEENS                   76.49      11.60
# 1    11385      107796     QUEENS                   45.05       6.46
# 2    11211      103123   BROOKLYN                   24.13       5.53
# 3    11208      101313   BROOKLYN                   40.58       6.01
# 4    10467      101255      BRONX                   52.08       5.68
# ..     ...         ...        ...                     ...        ...
# 184  10464        4531      BRONX                   42.02       5.01
# 185  10004        3335  MANHATTAN                    3.24      29.06
# 186  10006        3092  MANHATTAN                   10.83      16.04
# 187  10162        1486  MANHATTAN                   12.38       4.85
# 188  11430         206     QUEENS                   33.01       2.91
#
#      pct_american_indian_and_alaska_native  pct_black_or_african_american  \
# 0                                     0.09                           7.12
# 1                                     0.03                           1.77
# 2                                     0.19                           3.56
# 3                                     0.03                          48.89
# 4                                     0.35                          30.43
# ..                                     ...                            ...
# 184                                   0.00                           0.02
# 185                                   0.00                           3.96
# 186                                   0.00                           3.20
# 187                                   0.00                           0.00
# 188                                   0.00                          59.22
#
#      pct_white  pct_native_hawaiian_and_other_pacific_islander  \
# 0         3.73                                            0.00
# 1        45.28                                            0.00
# 2        64.24                                            0.02
# 3         2.71                                            0.00
# 4         9.24                                            0.02
# ..         ...                                             ...
# 184      52.50                                            0.00
# 185      59.28                                            0.51
# 186      64.52                                            0.00
# 187      79.48                                            0.00
# 188       4.85                                            0.00
#
#      pct_some_other_race  pct_two_or_more_races  pct_below_poverty
# 0                   0.37                   0.60              19.69
# 1                   0.32                   1.09              10.68
# 2                   0.29                   2.05              25.22
# 3                   0.76                   1.02              25.68
# 4                   0.76                   1.44              25.20
# ..                   ...                    ...                ...
# 184                 0.44                   0.00               7.11
# 185                 1.05                   2.91               1.32
# 186                 1.68                   3.72               3.36
# 187                 0.00                   3.30               0.00
# 188                 0.00                   0.00              72.77
#
# [189 rows x 12 columns]

# %% [markdown]
# ### Import packages

# %%
# %%R
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse
# In addition: Warning message:
# package ‘lubridate’ was built under R version 4.3.3

# %% [markdown]
# **Another way to import a package**
#
# Note that sometimes you might see
#
# ```R
# library('tidyverse')
# ```
#
# that also imports a library just the same as `require`
#
# **A note about tidyverse**
#
# The [Tidyverse](https://www.tidyverse.org/packages/) package is actually a bunch of other packages put together. So sometimes, you might see something like
#
# ```R
# require('ggplot2')
# require('readr')
# require('dplyr')
# require('tidyr')
# ```
#
# This also achieves the same purpose, but sometimes we just import the pakcages we need instead of the whole tidyverse.

# %% [markdown]
# ### Read Data
#
#
# This uses a function in the readr package to read a CSV file. Check out all the other cool things readr can do (like read from an excel file or a google doc)
#
# https://readr.tidyverse.org/

# %%
# %%R
#
# # Read data
# df <- read_csv('housing_data.csv')
# df
# Out:
# Rows: 189 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): borough
# dbl (11): zip, population, pct_hispanic_or_latino, pct_asian, pct_american_i...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 189 × 12
#      zip population borough  pct_hispanic_or_latino pct_asian
#    <dbl>      <dbl> <chr>                     <dbl>     <dbl>
#  1 11368     112088 QUEENS                    76.5      11.6
#  2 11385     107796 QUEENS                    45.0       6.46
#  3 11211     103123 BROOKLYN                  24.1       5.53
#  4 11208     101313 BROOKLYN                  40.6       6.01
#  5 10467     101255 BRONX                     52.1       5.68
#  6 11236     100844 BROOKLYN                   7.66      2.58
#  7 11226      99558 BROOKLYN                  16.4       3.07
#  8 11373      94437 QUEENS                    41.7      48.5
#  9 11234      93534 BROOKLYN                  11.1       7.19
# 10 11220      93170 BROOKLYN                  41.3      41.4
# # ℹ 179 more rows
# # ℹ 7 more variables: pct_american_indian_and_alaska_native <dbl>,
# #   pct_black_or_african_american <dbl>, pct_white <dbl>,
# #   pct_native_hawaiian_and_other_pacific_islander <dbl>,
# #   pct_some_other_race <dbl>, pct_two_or_more_races <dbl>,
# #   pct_below_poverty <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %%
df = pd.read_csv('housing_data.csv')

# %%
df.sort_values('pct_below_poverty', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.sort_values('pct_below_poverty', ascending=False).head(10)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Notice that the assignment operator is `<-` rather than `=`. Actually, both work. Check out this really angry person's guide to R syntax. There are a LOT of punctuation marks in R.
#
# ![Screenshot%202023-01-20%20at%2011.47.03%20AM.png](images/r-assignment-operator.png)
#
# source: http://arrgh.tim-smith.us/syntax.html

# %% [markdown]
# # ggplot2
# ![image.png](attachment:image.png)
#
#
# Wahoo! Those are the basics. Now let's plot some **univariate** distributions in ggplot.

# %% [markdown]
# ### Histogram

# %%
# %%R
#
# # Plot
# ggplot(df)

# %%
# %%R
#
# # Plot +
# # Aesthetics
# ggplot(df) +
#     aes(x=pct_below_poverty)

# %%
# %%R
#
# # Plot +
# # Aesthetics +
# # Geom
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
#
# # Plot +
# # Aesthetics +
# # Geom +
# # Theme
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a histogram (above), and the documentation for geom_histogram (link below). Read the documentation and adjust the bin sizes (there are two ways to do this)
#
# https://ggplot2.tidyverse.org/reference/geom_histogram.html

# %%
# %%R
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram(
#         binwidth = 10,
#         bins = 30,
#     )
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question

# %% [markdown]
# ### Dotplot

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_point()

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a dotplot. It's super hard to read, check out some ggplot documentation and see if you can figure out how to make the dots bigger. Also, let's make them less opaque (more transparant) so that we can see where they overlap.

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_point(color="blue", alpha=0.15, size=4)
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question

# %% [markdown]
# **👉 Bonus**:  what does `geom_rug()` do?
# 1. try applying it to the above chart
# 2. and then google the offical ggplot documentation for it

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_point(color="blue", alpha=0.15, size=4) +
#     geom_rug()
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Bonus" question

# %% [markdown]
# A rug plot is a compact visualisation designed to supplement a 2d display with the two 1d marginal distributions. Rug plots display individual cases so are best used with smaller datasets.

# %% [markdown]
# ### Dotplot (with jitter)

# %% [markdown]
# The jitter geom is a convenient shortcut for geom_point(position = "jitter"). It adds a small amount of random variation to the location of each point, and is a useful way of handling overplotting caused by discreteness in smaller datasets.

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_jitter()

# %% [markdown]
# ## NOTES
#
# In the line `aes(x=pct_below_poverty, y=1)`, the `y=1` is essentially fixing the `y` position of all your points at 1. This means all the data points are plotted at a constant `y` value of 1, and they will only vary along the `x` axis (which represents the `pct_below_poverty` variable).
#
# The `geom_jitter()` function adds a small random variation to the position of the points along the `y` axis to help prevent overplotting (i.e., when multiple points fall directly on top of each other). So, even though all your points are at `y=1`, jittering shifts them slightly up or down along the `y` axis in a random way to make each point visible.
#
# Regarding the scatter, you're seeing points spread out because jitter is adding a random shift to each point's `y` value. This prevents the points from being stacked directly on top of each other (which would make them harder to see). The effect you're noticing where the points appear more scattered is due to this random jittering.
#
# In summary:
# - The `y=1` means all points are initially at the same `y` coordinate (1).
# - The `geom_jitter()` function applies a small, random shift to the `y` position to avoid overplotting and make the points more visible, which leads to the scattered look.

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a dotplot (with jitter). It's a bit easier to read, but it's hard to make sense of since the y axis is meaningless. Read some documentation and learn how to:
#
# - Add a **title** and **subtitle** that helps explain what story this data is telling. <br/>
#     (_Remember, use a narrative title and a descriptive subtitle. The title should tell a story, the subtitle should say what the data is exactly._)

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_jitter()+
#     labs(
#     title = 'Seeing Poverty in New York City by Zipcode',
#     subtitle = 'The plot shows the percentage of people below poverty line by Zipcode in NYC. It is scattered for the purpose of ease to read the dots. '
#   )
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question

# %% [markdown]
# **👉 Bonus**
# - Remove the y axis labels (and text)
# - Improve the text on the X axis label
# - Change the default theme, explain why you picked the one you picked.

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_jitter()+
#     labs(
#     x = 'Percentage of People Below Poverty Line',
#     title = 'Seeing Poverty in New York City by Zipcode',
#     subtitle = 'The plot shows the percentage of people below poverty line by Zipcode in NYC. It is scattered for the purpose of ease to read the dots. '
#     ) +
#     theme_minimal()+
#     theme(
#         axis.text.y=element_blank(),  #remove y axis labels
#         axis.ticks.y=element_blank()  #remove y axis ticks
#         )
#
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Bonus" question

# %% [markdown]
# ### Density Plot

# %%
# %%R -w 1000 -h 200
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_density()

# %% [markdown]
# > Density Plot is the continuous and smoothed version of the Histogram estimated from the data. It is estimated through Kernel Density Estimation.
#
# Source: https://www.geeksforgeeks.org/histograms-and-density-plots-in-python/

# %% [markdown]
# 👉 Try It
#
# This one is entirely theoretical. Google around and then take your best shot at answering the following questions:
#
# 1) When might you want to use a density plot versus a histogram?
# > when you want to focus on the overall shape and smooth distribution of data rather than the count of each bin.
#
# 2) What is Kernel Density Estimation and how does it work?
# > Kernel (continuous curve) is drawn at every individual data point and then all these curves are added together to make a single smoothened density estimation

# %% [markdown]
# ### Box and Whisker Plot
# http://www.sthda.com/english/wiki/ggplot2-box-plot-quick-start-guide-r-software-and-data-visualization

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_boxplot(alpha=.2,outlier.size=10)

# %% [markdown]
# Box and whisker plots aren't super easy to read. We don't always use them in reader-facing visualizations, but you'll find them a lot in scientific papers. Box and whisker plots help draw attention to outliers in relation to the median and interquartile range of the data.

# %% [markdown]
# ##### Interpreting a Boxplot
# ![](images/boxplot-image.png)
# > **Not all boxplots are created equal!**
# >
# >"Not all boxplots are created equal. There are many different ways in which quantiles can be defined. For example, some will compute a quantile as (i−0.5)/n
#  where i
#  is the nth element of the batch of data and n
#  is the total number of elements in that batch. This is the method implemented by Bill Cleveland and we will refer to this method as Cleveland’s quantile method. This also happens to be the method implemented by the base’s boxplot function which explains the different boxplot output compared to ggplot_boxplot in our working example:
#
#
# source: https://mgimond.github.io/ES218/Week05a.html

# %% [markdown]
# **👉 Try It**
#
# Our box and whisker plot is showing three outliers with very high poverty rates. See if you can:
# - figure out how to annotate those so that we know which zipcodes they are
# - add a title and subtitle explaining to the reader what they're looking at
#
# **👉 Bonus**
# - Can you also annotate which borough the outliers are in?

# %%
df.sort_values('pct_below_poverty', ascending=False).head(10)
# Out:
#        zip  population    borough  pct_hispanic_or_latino  pct_asian  \
# 188  11430         206     QUEENS                   33.01       2.91
# 173  10474       12179      BRONX                   62.35       0.17
# 110  10454       37212      BRONX                   67.82       0.24
# 94   10455       41951      BRONX                   71.70       0.92
# 23   10453       81716      BRONX                   69.16       1.48
# 10   10456       92717      BRONX                   59.11       0.63
# 36   10457       74822      BRONX                   67.16       0.92
# 116  10035       36048  MANHATTAN                   45.61       3.70
# 34   10452       75452      BRONX                   69.44       1.55
# 79   10451       48136      BRONX                   60.69       1.36
#
#      pct_american_indian_and_alaska_native  pct_black_or_african_american  \
# 188                                   0.00                          59.22
# 173                                   0.10                          35.40
# 110                                   0.28                          27.28
# 94                                    0.23                          24.50
# 23                                    0.03                          26.49
# 10                                    0.60                          36.56
# 36                                    0.12                          29.38
# 116                                   0.16                          36.27
# 34                                    0.13                          25.80
# 79                                    0.10                          33.16
#
#      pct_white  pct_native_hawaiian_and_other_pacific_islander  \
# 188       4.85                                            0.00
# 173       1.54                                            0.00
# 110       3.52                                            0.00
# 94        1.57                                            0.26
# 23        1.48                                            0.00
# 10        1.66                                            0.00
# 36        1.24                                            0.00
# 116      11.48                                            0.07
# 34        1.82                                            0.03
# 79        3.31                                            0.00
#
#      pct_some_other_race  pct_two_or_more_races  pct_below_poverty
# 188                 0.00                   0.00              72.77
# 173                 0.38                   0.07              47.90
# 110                 0.40                   0.45              43.12
# 94                  0.40                   0.42              38.14
# 23                  0.58                   0.78              37.77
# 10                  0.42                   1.02              37.16
# 36                  0.43                   0.77              37.14
# 116                 1.23                   1.48              36.77
# 34                  0.41                   0.81              36.23
# 79                  0.48                   0.90              36.13

# %%
# %%R -w 1000 -h 200
#
# # modify this code
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_boxplot(alpha=.2,outlier.size=10) +
#     annotate("text", x = 43.12, y = 1.1, label = "Bronx") +
#     annotate("text", x = 47.90, y = 1.1, label = "Bronx") +
#     annotate("text", x = 72.77, y = 1.1, label = "Queens")

# %% [markdown]
# ### Violin Plot

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_violin()

# %% [markdown]
# **👉 Try It**
#
# Violin plots are great in that they help the reader to see nuances in the density a bit better than the box and whisker plot. However, they can be hard to interpret. Showing the dots in/on the violin plot can help.
#
# See if you can find a way to plot the dots in or on the violin plot to help the reader better understand what they're looking it.

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#   aes(x=pct_below_poverty, y=1) +
#   geom_violin() +
#   geom_jitter(width = 0.1)

# %% [markdown]
# ### Beeswarm
# (this requires installing a package)
#
# https://github.com/eclarke/ggbeeswarm

# %%
# %%R
#
# install.packages('ggbeeswarm')
# Out:
# --- Please select a CRAN mirror for use in this session ---
# Secure CRAN mirrors
#
#  1: 0-Cloud [https]
#  2: Australia (Canberra) [https]
#  3: Australia (Melbourne 1) [https]
#  4: Australia (Melbourne 2) [https]
#  5: Austria (Wien 1) [https]
#  6: Belgium (Brussels) [https]
#  7: Brazil (PR) [https]
#  8: Brazil (SP 1) [https]
#  9: Brazil (SP 2) [https]
# 10: Bulgaria [https]
# 11: Canada (MB) [https]
# 12: Canada (ON 1) [https]
# 13: Canada (ON 2) [https]
# 14: Chile (Santiago) [https]
# 15: China (Beijing 2) [https]
# 16: China (Beijing 3) [https]
# 17: China (Hefei) [https]
# 18: China (Hong Kong) [https]
# 19: China (Jinan) [https]
# 20: China (Lanzhou) [https]
# 21: China (Nanjing) [https]
# 22: China (Shanghai 2) [https]
# 23: China (Shenzhen) [https]
# 24: China (Wuhan) [https]
# 25: Colombia (Cali) [https]
# 26: Costa Rica [https]
# 27: Cyprus [https]
# 28: Czech Republic [https]
# 29: Denmark [https]
# 30: East Asia [https]
# 31: Ecuador (Cuenca) [https]
# 32: France (Lyon 1) [https]
# 33: France (Lyon 2) [https]
# 34: France (Marseille) [https]
# 35: France (Paris 1) [https]
# 36: Germany (Erlangen) [https]
# 37: Germany (Göttingen) [https]
# 38: Germany (Leipzig) [https]
# 39: Germany (Münster) [https]
# 40: Greece [https]
# 41: Iceland [https]
# 42: India (Bengaluru) [https]
# 43: India (Bhubaneswar) [https]
# 44: Indonesia (Banda Aceh) [https]
# 45: Iran (Mashhad) [https]
# 46: Italy (Milano) [https]
# 47: Italy (Padua) [https]
# 48: Japan (Yonezawa) [https]
# 49: Korea (Gyeongsan-si) [https]
# 50: Mexico (Mexico City) [https]
# 51: Mexico (Texcoco) [https]
# 52: Morocco [https]
# 53: Netherlands (Dronten) [https]
# 54: New Zealand [https]
# 55: South Africa (Johannesburg) [https]
# 56: Spain (A Coruña) [https]
# 57: Spain (Madrid) [https]
# 58: Sweden (Umeå) [https]
# 59: Switzerland (Zurich 1) [https]
# 60: Taiwan (Taipei) [https]
# 61: Turkey (Denizli) [https]
# 62: UK (Bristol) [https]
# 63: UK (London 1) [https]
# 64: USA (IA) [https]
# 65: USA (MI) [https]
# 66: USA (MO) [https]
# 67: USA (OH) [https]
# 68: USA (OR) [https]
# 69: USA (PA 1) [https]
# 70: USA (TN) [https]
# 71: USA (UT) [https]
# 72: United Arab Emirates [https]
# 73: Uruguay [https]
# 74: (other mirrors)
#
# Enter an item from the menu, or 0 to exit
#
# The downloaded binary packages are in
# 	/var/folders/bs/l0k9vd0978dgckqg6q8vr_fw0000gn/T//RtmpKmhs6l/downloaded_packages
# also installing the dependencies ‘beeswarm’, ‘vipor’
#
# trying URL 'https://cran.csiro.au/bin/macosx/big-sur-arm64/contrib/4.3/beeswarm_0.4.0.tgz'
# Content type 'application/x-gzip' length 83008 bytes (81 KB)
# ==================================================
# downloaded 81 KB
#
# trying URL 'https://cran.csiro.au/bin/macosx/big-sur-arm64/contrib/4.3/vipor_0.4.7.tgz'
# Content type 'application/x-gzip' length 4591264 bytes (4.4 MB)
# ==================================================
# downloaded 4.4 MB
#
# trying URL 'https://cran.csiro.au/bin/macosx/big-sur-arm64/contrib/4.3/ggbeeswarm_0.7.2.tgz'
# Content type 'application/x-gzip' length 1757649 bytes (1.7 MB)
# ==================================================
# downloaded 1.7 MB
#
# In addition: Warning message:
# In doTryCatch(return(expr), name, parentenv, handler) :
#   unable to load shared object '/Library/Frameworks/R.framework/Resources/modules//R_X11.so':
#   dlopen(/Library/Frameworks/R.framework/Resources/modules//R_X11.so, 0x0006): Library not loaded: /opt/X11/lib/libSM.6.dylib
#   Referenced from: <FFA47D77-8F35-36FC-B0E5-38351B8D9512> /Library/Frameworks/R.framework/Versions/4.3-arm64/Resources/modules/R_X11.so
#   Reason: tried: '/opt/X11/lib/libSM.6.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/X11/lib/libSM.6.dylib' (no such file), '/opt/X11/lib/libSM.6.dylib' (no such file), '/usr/local/lib/libSM.6.dylib' (no such file), '/usr/lib/libSM.6.dylib' (no such file, not in dyld cache)

# %% [markdown]
# **👉 Try It (Bonus!)**
#
# Install the package above and show the density as a beeswarm rather than just a jitter.

# %%
# %%R
# library(ggplot2)
# library(ggbeeswarm)
#
# # Compare jitter and beeswarm
# ggplot(df, aes(x = pct_below_poverty)) +
#   geom_jitter(width = 0.1, color = 'blue', alpha = 0.5) +   # Jitter plot
#   ggtitle("Comparison: Jitter vs Beeswarm") +
#   theme_minimal()
#
# ggplot(df, aes(x = pct_below_poverty)) +
#   geom_beeswarm(color = 'red', alpha = 0.5) +   # Beeswarm plot
#   ggtitle("Beeswarm Plot") +
#   theme_minimal()
# Out:
# Error in `ggplot()`:
# ! `data` cannot be a function.
# ℹ Have you misspelled the `data` argument in `ggplot()`
# Run `rlang::last_trace()` to see where the error occurred.
#
# Error in ggplot(df, aes(x = pct_below_poverty)) :
# ℹ Have you misspelled the `data` argument in `ggplot()`
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/rinterface.py:194, in evalr_expr_with_visible(expr, envir)
#     193 if error_occured[0]:
# --> 194     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     195 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in ggplot(df, aes(x = pct_below_poverty)) :
# ℹ Have you misspelled the `data` argument in `ggplot()`
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'library(ggplot2)\nlibrary(ggbeeswarm)\n\n# Compare jitter and beeswarm\nggplot(df, aes(x = pct_below_poverty)) + \n  geom_jitter(width = 0.1, color = \'blue\', alpha = 0.5) +   # Jitter plot\n  ggtitle("Comparison: Jitter vs Beeswarm") +\n  theme_minimal()\n\nggplot(df, aes(x = pct_below_poverty)) + \n  geom_beeswarm(color = \'red\', alpha = 0.5) +   # Beeswarm plot\n  ggtitle("Beeswarm Plot") +\n  theme_minimal()\n\n')
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:984, in RMagics.R(self, line, cell, local_ns)
#     982     if not e.stdout.endswith(e.err):
#     983         print(e.err)
# --> 984     raise e
#     985 finally:
#     986     if self.device in DEVICES_STATIC:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:413, in RMagics.eval(self, code)
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#     412     warning_or_other_msg = self.flush()
# --> 413     raise RInterpreterError(code, str(exception),
#     414                             warning_or_other_msg)
#     415 finally:
#     416     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line 'library(ggplot2)\nlibrary(ggbeeswarm)\n\n# Compare jitter and beeswarm\nggplot(df, aes(x = pct_below_poverty)) + \n  geom_jitter(width = 0.1, color = \'blue\', alpha = 0.5) +   # Jitter plot\n  ggtitle("Comparison: Jitter vs Beeswarm") +\n  theme_minimal()\n\nggplot(df, aes(x = pct_below_poverty)) + \n  geom_beeswarm(color = \'red\', alpha = 0.5) +   # Beeswarm plot\n  ggtitle("Beeswarm Plot") +\n  theme_minimal()\n\n'.
# R error message: 'Error in ggplot(df, aes(x = pct_below_poverty)) : \nℹ Have you misspelled the `data` argument in `ggplot()`'
